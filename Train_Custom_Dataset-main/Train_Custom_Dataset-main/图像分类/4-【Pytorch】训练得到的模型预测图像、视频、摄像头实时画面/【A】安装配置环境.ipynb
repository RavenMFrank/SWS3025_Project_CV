#      ---------------------------------        31.7/38.1 MB 4.0 MB/s eta 0:00:02
#      ---------------------------------        31.8/38.1 MB 3.8 MB/s eta 0:00:02
#      ---------------------------------        32.0/38.1 MB 3.8 MB/s eta 0:00:02
#      ---------------------------------        32.3/38.1 MB 3.8 MB/s eta 0:00:02
#      ----------------------------------       32.4/38.1 MB 3.8 MB/s eta 0:00:02
#      ----------------------------------       32.5/38.1 MB 3.7 MB/s eta 0:00:02
#      ----------------------------------       32.7/38.1 MB 3.7 MB/s eta 0:00:02
#      ----------------------------------       32.7/38.1 MB 3.7 MB/s eta 0:00:02
#      ----------------------------------       32.7/38.1 MB 3.7 MB/s eta 0:00:02
#      ----------------------------------       32.7/38.1 MB 3.7 MB/s eta 0:00:02
#      ----------------------------------       32.7/38.1 MB 3.7 MB/s eta 0:00:02
#      ----------------------------------       32.7/38.1 MB 3.7 MB/s eta 0:00:02
#      ----------------------------------       32.7/38.1 MB 3.7 MB/s eta 0:00:02
#      ----------------------------------       32.7/38.1 MB 3.7 MB/s eta 0:00:02
#      ----------------------------------       32.7/38.1 MB 3.7 MB/s eta 0:00:02
#      ----------------------------------       32.7/38.1 MB 3.7 MB/s eta 0:00:02
#      -------------------------------------    35.5/38.1 MB 3.8 MB/s eta 0:00:01
#      -------------------------------------    35.5/38.1 MB 3.8 MB/s eta 0:00:01
#      -------------------------------------    35.5/38.1 MB 3.8 MB/s eta 0:00:01
#      -------------------------------------    35.5/38.1 MB 3.8 MB/s eta 0:00:01
#      -------------------------------------    35.5/38.1 MB 3.5 MB/s eta 0:00:01
#      -------------------------------------    35.9/38.1 MB 3.4 MB/s eta 0:00:01
#      --------------------------------------   36.2/38.1 MB 4.3 MB/s eta 0:00:01
#      --------------------------------------   36.4/38.1 MB 4.3 MB/s eta 0:00:01
#      --------------------------------------   36.9/38.1 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------------  37.2/38.1 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------  37.5/38.1 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------------  37.7/38.1 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------  38.1/38.1 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------  38.1/38.1 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------  38.1/38.1 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------- 38.1/38.1 MB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\users\20363\anaconda3\lib\site-packages (9.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\20363\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\20363\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\20363\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\20363\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\20363\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\20363\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\20363\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\20363\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\20363\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\20363\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\20363\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\20363\anaconda3\lib\site-packages (from requests) (2023.5.7)
# Requirement already satisfied: colorama in c:\users\20363\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\20363\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.0.74

# %% [markdown]
# ## 下载安装Pytorch

# %%
# !pip3 install torch
# Out:
# Requirement already satisfied: torch in c:\users\20363\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: filelock in c:\users\20363\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\20363\anaconda3\lib\site-packages (from torch) (4.6.3)
# Requirement already satisfied: sympy in c:\users\20363\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\20363\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\20363\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\20363\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\20363\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)

# %% [markdown]
# ## 下载安装 mmcv-full

# %%
# 安装mmcv -full
# !pip install mmcv-full
# Out:
# Collecting mmcv-full
#   Using cached mmcv-full-1.7.1.tar.gz (605 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting addict (from mmcv-full)
#   Using cached addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: numpy in c:\users\20363\anaconda3\lib\site-packages (from mmcv-full) (1.24.3)
# Requirement already satisfied: packaging in c:\users\20363\anaconda3\lib\site-packages (from mmcv-full) (23.0)
# Requirement already satisfied: Pillow in c:\users\20363\anaconda3\lib\site-packages (from mmcv-full) (9.4.0)
# Requirement already satisfied: pyyaml in c:\users\20363\anaconda3\lib\site-packages (from mmcv-full) (6.0)
# Requirement already satisfied: yapf in c:\users\20363\anaconda3\lib\site-packages (from mmcv-full) (0.31.0)
# Requirement already satisfied: regex in c:\users\20363\anaconda3\lib\site-packages (from mmcv-full) (2022.7.9)
# Building wheels for collected packages: mmcv-full
#   Building wheel for mmcv-full (setup.py): started
#   Building wheel for mmcv-full (setup.py): finished with status 'error'
#   Running setup.py clean for mmcv-full
# Failed to build mmcv-full
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [1549 lines of output]
#   No CUDA runtime is found, using CUDA_HOME='C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.2'
#   Compiling mmcv._ext only with CPU
#   running bdist_wheel
#   C:\Users\20363\anaconda3\Lib\site-packages\torch\utils\cpp_extension.py:476: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#     warnings.warn(msg.format('we could not find ninja.'))
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-311
#   creating build\lib.win-amd64-cpython-311\mmcv
#   copying mmcv\version.py -> build\lib.win-amd64-cpython-311\mmcv
#   copying mmcv\__init__.py -> build\lib.win-amd64-cpython-311\mmcv
#   creating build\lib.win-amd64-cpython-311\mmcv\arraymisc
#   copying mmcv\arraymisc\quantization.py -> build\lib.win-amd64-cpython-311\mmcv\arraymisc
#   copying mmcv\arraymisc\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\arraymisc
#   creating build\lib.win-amd64-cpython-311\mmcv\cnn
#   copying mmcv\cnn\alexnet.py -> build\lib.win-amd64-cpython-311\mmcv\cnn
#   copying mmcv\cnn\builder.py -> build\lib.win-amd64-cpython-311\mmcv\cnn
#   copying mmcv\cnn\resnet.py -> build\lib.win-amd64-cpython-311\mmcv\cnn
#   copying mmcv\cnn\vgg.py -> build\lib.win-amd64-cpython-311\mmcv\cnn
#   copying mmcv\cnn\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\cnn
#   creating build\lib.win-amd64-cpython-311\mmcv\device
#   copying mmcv\device\scatter_gather.py -> build\lib.win-amd64-cpython-311\mmcv\device
#   copying mmcv\device\utils.py -> build\lib.win-amd64-cpython-311\mmcv\device
#   copying mmcv\device\_functions.py -> build\lib.win-amd64-cpython-311\mmcv\device
#   copying mmcv\device\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\device
#   creating build\lib.win-amd64-cpython-311\mmcv\engine
#   copying mmcv\engine\test.py -> build\lib.win-amd64-cpython-311\mmcv\engine
#   copying mmcv\engine\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\engine
#   creating build\lib.win-amd64-cpython-311\mmcv\fileio
#   copying mmcv\fileio\file_client.py -> build\lib.win-amd64-cpython-311\mmcv\fileio
#   copying mmcv\fileio\io.py -> build\lib.win-amd64-cpython-311\mmcv\fileio
#   copying mmcv\fileio\parse.py -> build\lib.win-amd64-cpython-311\mmcv\fileio
#   copying mmcv\fileio\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\fileio
#   creating build\lib.win-amd64-cpython-311\mmcv\image
#   copying mmcv\image\colorspace.py -> build\lib.win-amd64-cpython-311\mmcv\image
#   copying mmcv\image\geometric.py -> build\lib.win-amd64-cpython-311\mmcv\image
#   copying mmcv\image\io.py -> build\lib.win-amd64-cpython-311\mmcv\image
#   copying mmcv\image\misc.py -> build\lib.win-amd64-cpython-311\mmcv\image
#   copying mmcv\image\photometric.py -> build\lib.win-amd64-cpython-311\mmcv\image
#   copying mmcv\image\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\image
#   creating build\lib.win-amd64-cpython-311\mmcv\onnx
#   copying mmcv\onnx\info.py -> build\lib.win-amd64-cpython-311\mmcv\onnx
#   copying mmcv\onnx\symbolic.py -> build\lib.win-amd64-cpython-311\mmcv\onnx
#   copying mmcv\onnx\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\onnx
#   creating build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\active_rotated_filter.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\assign_score_withk.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\ball_query.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\bbox.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\border_align.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\box_iou_quadri.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\box_iou_rotated.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\carafe.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\cc_attention.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\chamfer_distance.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\contour_expand.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\convex_iou.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\corner_pool.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\correlation.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\deform_conv.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\deform_roi_pool.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\deprecated_wrappers.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\diff_iou_rotated.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\focal_loss.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\furthest_point_sample.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\fused_bias_leakyrelu.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\gather_points.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\group_points.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\info.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\iou3d.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\knn.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\masked_conv.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\merge_cells.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\min_area_polygons.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\modulated_deform_conv.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\multi_scale_deform_attn.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\nms.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\pixel_group.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\points_in_boxes.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\points_in_polygons.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\points_sampler.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\point_sample.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\prroi_pool.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\psa_mask.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\riroi_align_rotated.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\roiaware_pool3d.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\roipoint_pool3d.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\roi_align.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\roi_align_rotated.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\roi_pool.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\rotated_feature_align.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\saconv.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\scatter_points.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\sparse_conv.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\sparse_functional.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\sparse_modules.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\sparse_ops.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\sparse_pool.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\sparse_structure.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\sync_bn.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\three_interpolate.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\three_nn.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\tin_shift.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\upfirdn2d.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\voxelize.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   copying mmcv\ops\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\ops
#   creating build\lib.win-amd64-cpython-311\mmcv\parallel
#   copying mmcv\parallel\collate.py -> build\lib.win-amd64-cpython-311\mmcv\parallel
#   copying mmcv\parallel\data_container.py -> build\lib.win-amd64-cpython-311\mmcv\parallel
#   copying mmcv\parallel\data_parallel.py -> build\lib.win-amd64-cpython-311\mmcv\parallel
#   copying mmcv\parallel\distributed.py -> build\lib.win-amd64-cpython-311\mmcv\parallel
#   copying mmcv\parallel\distributed_deprecated.py -> build\lib.win-amd64-cpython-311\mmcv\parallel
#   copying mmcv\parallel\registry.py -> build\lib.win-amd64-cpython-311\mmcv\parallel
#   copying mmcv\parallel\scatter_gather.py -> build\lib.win-amd64-cpython-311\mmcv\parallel
#   copying mmcv\parallel\utils.py -> build\lib.win-amd64-cpython-311\mmcv\parallel
#   copying mmcv\parallel\_functions.py -> build\lib.win-amd64-cpython-311\mmcv\parallel
#   copying mmcv\parallel\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\parallel
#   creating build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\base_module.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\base_runner.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\builder.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\checkpoint.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\default_constructor.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\dist_utils.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\epoch_based_runner.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\fp16_utils.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\iter_based_runner.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\log_buffer.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\priority.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\utils.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   copying mmcv\runner\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\runner
#   creating build\lib.win-amd64-cpython-311\mmcv\tensorrt
#   copying mmcv\tensorrt\init_plugins.py -> build\lib.win-amd64-cpython-311\mmcv\tensorrt
#   copying mmcv\tensorrt\preprocess.py -> build\lib.win-amd64-cpython-311\mmcv\tensorrt
#   copying mmcv\tensorrt\tensorrt_utils.py -> build\lib.win-amd64-cpython-311\mmcv\tensorrt
#   copying mmcv\tensorrt\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\tensorrt
#   creating build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\config.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\device_type.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\env.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\ext_loader.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\hub.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\logging.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\misc.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\parrots_jit.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\parrots_wrapper.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\path.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\progressbar.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\registry.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\seed.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\testing.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\timer.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\torch_ops.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\trace.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\version_utils.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   copying mmcv\utils\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\utils
#   creating build\lib.win-amd64-cpython-311\mmcv\video
#   copying mmcv\video\io.py -> build\lib.win-amd64-cpython-311\mmcv\video
#   copying mmcv\video\optflow.py -> build\lib.win-amd64-cpython-311\mmcv\video
#   copying mmcv\video\processing.py -> build\lib.win-amd64-cpython-311\mmcv\video
#   copying mmcv\video\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\video
#   creating build\lib.win-amd64-cpython-311\mmcv\visualization
#   copying mmcv\visualization\color.py -> build\lib.win-amd64-cpython-311\mmcv\visualization
#   copying mmcv\visualization\image.py -> build\lib.win-amd64-cpython-311\mmcv\visualization
#   copying mmcv\visualization\optflow.py -> build\lib.win-amd64-cpython-311\mmcv\visualization
#   copying mmcv\visualization\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\visualization
#   creating build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\activation.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\context_block.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\conv.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\conv2d_adaptive_padding.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\conv_module.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\conv_ws.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\depthwise_separable_conv_module.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\drop.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\generalized_attention.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\hsigmoid.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\hswish.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\non_local.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\norm.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\padding.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\plugin.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\registry.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\scale.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\swish.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\transformer.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\upsample.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\wrappers.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   copying mmcv\cnn\bricks\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\bricks
#   creating build\lib.win-amd64-cpython-311\mmcv\cnn\rfsearch
#   copying mmcv\cnn\rfsearch\operator.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\rfsearch
#   copying mmcv\cnn\rfsearch\search.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\rfsearch
#   copying mmcv\cnn\rfsearch\utils.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\rfsearch
#   copying mmcv\cnn\rfsearch\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\rfsearch
#   creating build\lib.win-amd64-cpython-311\mmcv\cnn\utils
#   copying mmcv\cnn\utils\flops_counter.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\utils
#   copying mmcv\cnn\utils\fuse_conv_bn.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\utils
#   copying mmcv\cnn\utils\sync_bn.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\utils
#   copying mmcv\cnn\utils\weight_init.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\utils
#   copying mmcv\cnn\utils\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\cnn\utils
#   creating build\lib.win-amd64-cpython-311\mmcv\device\ipu
#   copying mmcv\device\ipu\dataloader.py -> build\lib.win-amd64-cpython-311\mmcv\device\ipu
#   copying mmcv\device\ipu\hierarchical_data_manager.py -> build\lib.win-amd64-cpython-311\mmcv\device\ipu
#   copying mmcv\device\ipu\hook_wrapper.py -> build\lib.win-amd64-cpython-311\mmcv\device\ipu
#   copying mmcv\device\ipu\model_wrapper.py -> build\lib.win-amd64-cpython-311\mmcv\device\ipu
#   copying mmcv\device\ipu\runner.py -> build\lib.win-amd64-cpython-311\mmcv\device\ipu
#   copying mmcv\device\ipu\utils.py -> build\lib.win-amd64-cpython-311\mmcv\device\ipu
#   copying mmcv\device\ipu\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\device\ipu
#   creating build\lib.win-amd64-cpython-311\mmcv\device\mlu
#   copying mmcv\device\mlu\data_parallel.py -> build\lib.win-amd64-cpython-311\mmcv\device\mlu
#   copying mmcv\device\mlu\distributed.py -> build\lib.win-amd64-cpython-311\mmcv\device\mlu
#   copying mmcv\device\mlu\scatter_gather.py -> build\lib.win-amd64-cpython-311\mmcv\device\mlu
#   copying mmcv\device\mlu\_functions.py -> build\lib.win-amd64-cpython-311\mmcv\device\mlu
#   copying mmcv\device\mlu\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\device\mlu
#   creating build\lib.win-amd64-cpython-311\mmcv\device\mps
#   copying mmcv\device\mps\data_parallel.py -> build\lib.win-amd64-cpython-311\mmcv\device\mps
#   copying mmcv\device\mps\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\device\mps
#   creating build\lib.win-amd64-cpython-311\mmcv\device\npu
#   copying mmcv\device\npu\data_parallel.py -> build\lib.win-amd64-cpython-311\mmcv\device\npu
#   copying mmcv\device\npu\distributed.py -> build\lib.win-amd64-cpython-311\mmcv\device\npu
#   copying mmcv\device\npu\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\device\npu
#   creating build\lib.win-amd64-cpython-311\mmcv\fileio\handlers
#   copying mmcv\fileio\handlers\base.py -> build\lib.win-amd64-cpython-311\mmcv\fileio\handlers
#   copying mmcv\fileio\handlers\json_handler.py -> build\lib.win-amd64-cpython-311\mmcv\fileio\handlers
#   copying mmcv\fileio\handlers\pickle_handler.py -> build\lib.win-amd64-cpython-311\mmcv\fileio\handlers
#   copying mmcv\fileio\handlers\yaml_handler.py -> build\lib.win-amd64-cpython-311\mmcv\fileio\handlers
#   copying mmcv\fileio\handlers\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\fileio\handlers
#   creating build\lib.win-amd64-cpython-311\mmcv\onnx\onnx_utils
#   copying mmcv\onnx\onnx_utils\symbolic_helper.py -> build\lib.win-amd64-cpython-311\mmcv\onnx\onnx_utils
#   copying mmcv\onnx\onnx_utils\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\onnx\onnx_utils
#   creating build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\checkpoint.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\closure.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\ema.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\evaluation.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\hook.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\iter_timer.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\lr_updater.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\memory.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\momentum_updater.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\optimizer.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\profiler.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\sampler_seed.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\sync_buffer.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   copying mmcv\runner\hooks\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks
#   creating build\lib.win-amd64-cpython-311\mmcv\runner\optimizer
#   copying mmcv\runner\optimizer\builder.py -> build\lib.win-amd64-cpython-311\mmcv\runner\optimizer
#   copying mmcv\runner\optimizer\default_constructor.py -> build\lib.win-amd64-cpython-311\mmcv\runner\optimizer
#   copying mmcv\runner\optimizer\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\runner\optimizer
#   creating build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\base.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\clearml.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\dvclive.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\mlflow.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\neptune.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\pavi.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\segmind.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\tensorboard.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\text.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\wandb.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   copying mmcv\runner\hooks\logger\__init__.py -> build\lib.win-amd64-cpython-311\mmcv\runner\hooks\logger
#   running egg_info
#   writing mmcv_full.egg-info\PKG-INFO
#   writing dependency_links to mmcv_full.egg-info\dependency_links.txt
#   writing requirements to mmcv_full.egg-info\requires.txt
#   writing top-level names to mmcv_full.egg-info\top_level.txt
#   reading manifest file 'mmcv_full.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: manifest_maker: MANIFEST.in, line 7: path 'mmcv/ops/csrc/' cannot end with '/'
#
#   adding license file 'LICENSE'
#   adding license file 'LICENSES.md'
#   writing manifest file 'mmcv_full.egg-info\SOURCES.txt'
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.model_zoo' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.model_zoo' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.model_zoo' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.model_zoo' to be distributed and are
#           already explicitly excluding 'mmcv.model_zoo' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.cuda' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.cuda' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.cuda' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.cuda' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.cuda' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.cuda.spconv' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.cuda.spconv' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.cuda.spconv' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.cuda.spconv' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.cuda.spconv' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.mlu' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.mlu' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.mlu' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.mlu' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.mlu' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.mps' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.mps' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.mps' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.mps' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.mps' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.utils.spconv' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.utils.spconv' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.utils.spconv' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.utils.spconv' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.utils.spconv' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.utils.spconv.spconv' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.utils.spconv.spconv' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.utils.spconv.spconv' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.utils.spconv.spconv' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.utils.spconv.spconv' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.common.utils.spconv.tensorview' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.common.utils.spconv.tensorview' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.common.utils.spconv.tensorview' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.common.utils.spconv.tensorview' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.common.utils.spconv.tensorview' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.onnxruntime' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.onnxruntime' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.onnxruntime' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.onnxruntime' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.onnxruntime' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.onnxruntime.cpu' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.onnxruntime.cpu' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mmcv.ops.csrc.onnxruntime.cpu' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mmcv.ops.csrc.onnxruntime.cpu' to be distributed and are
#           already explicitly excluding 'mmcv.ops.csrc.onnxruntime.cpu' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\20363\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'mmcv.ops.csrc.parrots' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mmcv.ops.csrc.parrots' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
# ...
#   copying mmcv\ops\csrc\pytorch\cpu\deform_conv.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\modulated_deform_conv.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\nms.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\nms_quadri.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\nms_rotated.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\pixel_group.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\points_in_boxes.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\psamask.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\roi_align.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\roi_align_rotated.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\rotated_feature_align.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\sparse_indice.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\sparse_maxpool.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\sparse_reordering.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   copying mmcv\ops\csrc\pytorch\cpu\voxelization.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cpu
#   creating build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\active_rotated_filter_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\assign_score_withk_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\ball_query_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\bbox_overlaps_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\border_align_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\box_iou_quadri_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\box_iou_rotated_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\carafe_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\carafe_naive_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\chamfer_distance_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\convex_iou.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\correlation_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\cudabind.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\deform_conv_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\deform_roi_pool_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\diff_iou_rotated_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\focal_loss_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\furthest_point_sample_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\fused_bias_leakyrelu_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\fused_spconv_ops_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\gather_points_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\group_points_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\iou3d_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\knn_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\masked_conv2d_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\min_area_polygons.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\modulated_deform_conv_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\ms_deform_attn_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\nms_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\nms_quadri_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\nms_rotated_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\points_in_boxes_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\points_in_polygons_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\prroi_pool_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\psamask_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\riroi_align_rotated_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\roi_align_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\roi_align_rotated_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\roi_pool_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\roiaware_pool3d_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\roipoint_pool3d_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\rotated_feature_align_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\scatter_points_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\sparse_indice.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\sparse_maxpool.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\sparse_pool_ops_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\sparse_reordering.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\spconv_ops_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\stack_ball_query_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\stack_group_points_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\sync_bn_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\three_interpolate_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\three_nn_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\tin_shift_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\upfirdn2d_kernel.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   copying mmcv\ops\csrc\pytorch\cuda\voxelization_cuda.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\cuda
#   creating build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\bbox_overlaps_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\carafe_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\deform_roi_pool_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\focal_loss_sigmoid_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\iou3d_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\masked_conv2d_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\ms_deform_attn_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\nms_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\psamask_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\roi_align_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\roi_align_rotated_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\roi_pool_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\roiaware_pool3d_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\roipoint_pool3d_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\three_nn_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   copying mmcv\ops\csrc\pytorch\mlu\tin_shift_mlu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mlu
#   creating build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mps
#   copying mmcv\ops\csrc\pytorch\mps\bbox_overlaps_mps.mm -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\mps
#   creating build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\deform_roi_pool.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\focal_loss_npu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\fused_bias_leakyrelu_npu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\npu
#   copying mmcv\ops\csrc\pytorch\npu\nms_npu.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\pytorch\npu
#   creating build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_corner_pool.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_cuda_helper.cuh -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_cummaxmin.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_deform_conv.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_grid_sampler.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_instance_norm.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_modulated_deform_conv.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_nms.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_plugin.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_plugin_helper.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_roi_align.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_scatternd.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   copying mmcv\ops\csrc\tensorrt\trt_serialize.hpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt
#   creating build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_corner_pool.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_corner_pool_kernel.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_cuda_helper.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_cummaxmin.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_cummaxmin_kernel.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_deform_conv.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_deform_conv_kernel.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_grid_sampler.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_grid_sampler_kernel.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_instance_norm.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_modulated_deform_conv.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_modulated_deform_conv_kernel.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_nms.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_nms_kernel.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_plugin.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_roi_align.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_roi_align_kernel.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_scatternd.cpp -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   copying mmcv\ops\csrc\tensorrt\plugins\trt_scatternd_kernel.cu -> build\lib.win-amd64-cpython-311\mmcv\ops\csrc\tensorrt\plugins
#   running build_ext
#   C:\Users\20363\anaconda3\Lib\site-packages\torch\utils\cpp_extension.py:359: UserWarning: Error checking compiler version for cl: [WinError 2] 系统找不到指定的文件。
#     warnings.warn(f'Error checking compiler version for {compiler}: {error}')
#   building 'mmcv._ext' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for mmcv-full
# ERROR: Could not build wheels for mmcv-full, which is required to install pyproject.toml-based projects

# %% [markdown]
# ## 下载中文字体文件

# %%
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/dataset/SimHei.ttf
# Out:
# 'wget' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %% [markdown]
# ## 创建目录

# %%
import os

# %%
# 存放测试图片
os.mkdir('test_img')

# 存放结果文件
os.mkdir('output')

# 存放训练得到的模型权重
os.mkdir('checkpoint')

# %%
# 下载样例模型文件
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/checkpoints/fruit30_pytorch_20220814.pth -P checkpoint

# 下载 类别名称 和 ID索引号 的映射字典
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/dataset/fruit30/idx_to_labels.npy
# Out:
# --2023-03-26 18:11:17--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/checkpoints/fruit30_pytorch_20220814.pth
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 44854477 (43M) [binary/octet-stream]
# 正在保存至: “checkpoint/fruit30_pytorch_20220814.pth”
#
# fruit30_pytorch_202 100%[===================>]  42.78M  37.4MB/s    用时 1.1s
#
# 2023-03-26 18:11:18 (37.4 MB/s) - 已保存 “checkpoint/fruit30_pytorch_20220814.pth” [44854477/44854477])
#
# --2023-03-26 18:11:18--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/dataset/fruit30/idx_to_labels.npy
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 769 [binary/octet-stream]
# 正在保存至: “idx_to_labels.npy.1”
#
# idx_to_labels.npy.1 100%[===================>]     769  --.-KB/s    用时 0s
#
# 2023-03-26 18:11:19 (18.8 MB/s) - 已保存 “idx_to_labels.npy.1” [769/769])

# %%
# 下载测试图像文件 至 test_img 文件夹

# !wget https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_fruits.jpg -P test_img

# !wget https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_orange_2.jpg -P test_img 

# !wget https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_bananan.jpg -P test_img

# !wget https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_kiwi.jpg -P test_img

# !wget https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_石榴.jpg -P test_img

# !wget https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_orange.jpg -P test_img

# !wget https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_lemon.jpg -P test_img

# !wget https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_火龙果.jpg -P test_img

# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/test/watermelon1.jpg -P test_img

# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/test/banana1.jpg -P test_img

# 下载测试视频文件 至 test_img 文件夹

# !wget https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/fruits_video.mp4 -P test_img
# Out:
# --2023-03-26 18:11:23--  https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_fruits.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 2579427 (2.5M) [image/jpeg]
# 正在保存至: “test_img/test_fruits.jpg”
#
# test_fruits.jpg     100%[===================>]   2.46M  6.74MB/s    用时 0.4s
#
# 2023-03-26 18:11:24 (6.74 MB/s) - 已保存 “test_img/test_fruits.jpg” [2579427/2579427])
#
# --2023-03-26 18:11:24--  https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_orange_2.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 1771019 (1.7M) [image/jpeg]
# 正在保存至: “test_img/test_orange_2.jpg”
#
# test_orange_2.jpg   100%[===================>]   1.69M  5.71MB/s    用时 0.3s
#
# 2023-03-26 18:11:24 (5.71 MB/s) - 已保存 “test_img/test_orange_2.jpg” [1771019/1771019])
#
# --2023-03-26 18:11:24--  https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_bananan.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 1116714 (1.1M) [image/jpeg]
# 正在保存至: “test_img/test_bananan.jpg”
#
# test_bananan.jpg    100%[===================>]   1.06M  3.48MB/s    用时 0.3s
#
# 2023-03-26 18:11:26 (3.48 MB/s) - 已保存 “test_img/test_bananan.jpg” [1116714/1116714])
#
# --2023-03-26 18:11:26--  https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_kiwi.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 1555297 (1.5M) [image/jpeg]
# 正在保存至: “test_img/test_kiwi.jpg”
#
# test_kiwi.jpg       100%[===================>]   1.48M  4.96MB/s    用时 0.3s
#
# 2023-03-26 18:11:27 (4.96 MB/s) - 已保存 “test_img/test_kiwi.jpg” [1555297/1555297])
#
# --2023-03-26 18:11:27--  https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_%E7%9F%B3%E6%A6%B4.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 1326649 (1.3M) [image/jpeg]
# 正在保存至: “test_img/test_石榴.jpg”
#
# test_石榴.jpg       100%[===================>]   1.26M  4.68MB/s    用时 0.3s
#
# 2023-03-26 18:11:28 (4.68 MB/s) - 已保存 “test_img/test_石榴.jpg” [1326649/1326649])
#
# --2023-03-26 18:11:28--  https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_orange.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 1283008 (1.2M) [image/jpeg]
# 正在保存至: “test_img/test_orange.jpg”
#
# test_orange.jpg     100%[===================>]   1.22M  4.45MB/s    用时 0.3s
#
# 2023-03-26 18:11:28 (4.45 MB/s) - 已保存 “test_img/test_orange.jpg” [1283008/1283008])
#
# --2023-03-26 18:11:28--  https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_lemon.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 983324 (960K) [image/jpeg]
# 正在保存至: “test_img/test_lemon.jpg”
#
# test_lemon.jpg      100%[===================>] 960.28K  3.50MB/s    用时 0.3s
#
# 2023-03-26 18:11:29 (3.50 MB/s) - 已保存 “test_img/test_lemon.jpg” [983324/983324])
#
# --2023-03-26 18:11:29--  https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/test_%E7%81%AB%E9%BE%99%E6%9E%9C.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 1385692 (1.3M) [image/jpeg]
# 正在保存至: “test_img/test_火龙果.jpg”
#
# test_火龙果.jpg     100%[===================>]   1.32M  4.72MB/s    用时 0.3s
#
# 2023-03-26 18:11:29 (4.72 MB/s) - 已保存 “test_img/test_火龙果.jpg” [1385692/1385692])
#
# --2023-03-26 18:11:30--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/test/watermelon1.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 429666 (420K) [image/jpeg]
# 正在保存至: “test_img/watermelon1.jpg”
#
# watermelon1.jpg     100%[===================>] 419.60K  2.00MB/s    用时 0.2s
#
# 2023-03-26 18:11:30 (2.00 MB/s) - 已保存 “test_img/watermelon1.jpg” [429666/429666])
#
# --2023-03-26 18:11:30--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/test/banana1.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 463879 (453K) [image/jpeg]
# 正在保存至: “test_img/banana1.jpg”
#
# banana1.jpg         100%[===================>] 453.01K  2.18MB/s    用时 0.2s
#
# 2023-03-26 18:11:31 (2.18 MB/s) - 已保存 “test_img/banana1.jpg” [463879/463879])
#
# --2023-03-26 18:11:31--  https://zihao-openmmlab.obs.myhuaweicloud.com/20220716-mmclassification/test/0818/fruits_video.mp4
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 17320366 (17M) [video/mp4]
# 正在保存至: “test_img/fruits_video.mp4”
#
# fruits_video.mp4    100%[===================>]  16.52M  23.5MB/s    用时 0.7s
#
# 2023-03-26 18:11:32 (23.5 MB/s) - 已保存 “test_img/fruits_video.mp4” [17320366/17320366])

# %% [markdown]
# ## 设置matplotlib中文字体

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# # windows操作系统
# plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签 
# plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# %%
# Mac操作系统，参考 https://www.ngui.cc/51cto/show-727683.html
# 下载 simhei.ttf 字体文件
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/dataset/SimHei.ttf

# %%
# Linux操作系统，例如 云GPU平台：https://featurize.cn/?s=d7ce99f842414bfcaea5662a97581bd1
# 如果报错 Unable to establish SSL connection.，重新运行本代码块即可
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/dataset/SimHei.ttf -O /environment/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/SimHei.ttf --no-check-certificate
# !rm -rf /home/featurize/.cache/matplotlib

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rc("font",family='SimHei') # 中文字体
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号
# Out:
# --2023-03-26 18:11:40--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/dataset/SimHei.ttf
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 10050868 (9.6M) [application/x-font-ttf]
# 正在保存至: “/environment/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/SimHei.ttf”
#
# /environment/minico 100%[===================>]   9.58M  18.0MB/s    用时 0.5s
#
# 2023-03-26 18:11:41 (18.0 MB/s) - 已保存 “/environment/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/SimHei.ttf” [10050868/10050868])

# %%
plt.plot([1,2,3], [100,500,300])
plt.title('matplotlib中文字体测试', fontsize=25)
plt.xlabel('X轴', fontsize=15)
plt.ylabel('Y轴', fontsize=15)
plt.show()
